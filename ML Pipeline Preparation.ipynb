# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('words')
nltk.download('wordnet')

import string
import pandas as pd
from sqlalchemy import create_engine
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords, wordnet
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import contractions
from sklearn.model_selection import train_test_split
import enchant
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/spmccar/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/spmccar/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package punkt to /home/spmccar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/spmccar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /home/spmccar/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/spmccar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql('SELECT * FROM Messages', engine)
df.head()
X = df['message'].values
Y = df.iloc[:,4:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data
# https://stackoverflow.com/questions/34293875/how-to-remove-punctuation-marks-from-a-string-in-python-3-x-using-translate/34294022
#
# https://stackoverflow.com/questions/15586721/wordnet-lemmatization-and-pos-tagging-in-python
#
# https://stackoverflow.com/questions/40144473/do-we-need-to-use-stopwords-filtering-before-pos-tagging
#
# https://stackoverflow.com/questions/27673527/how-should-i-vectorize-the-following-list-of-lists-with-scikit-learn
#
# https://stackoverflow.com/questions/34293875/how-to-remove-punctuation-marks-from-a-string-in-python-3-x-using-translate/34294022
#
# https://en.wiktionary.org/wiki/Category_talk:English_one_letter_words
#
# https://stackoverflow.com/questions/3788870/how-to-check-if-a-word-is-an-english-word-with-python
#
# https://stackoverflow.com/questions/3788870/how-to-check-if-a-word-is-an-english-word-with-python

# %%
english_stopwords = stopwords.words('english')

lemmatizer = WordNetLemmatizer()

translator = str.maketrans('', '', string.punctuation)

def tokenize(text, 
             translator,
             english_stopwords,
             lemmatizer):

    clean_text = contractions.fix(text)

    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    clean_text = re.sub(url_regex, ' ', clean_text)

    clean_text = re.sub('http[a-zA-Z\s&\.]+\s', ' ', clean_text)
    clean_text = re.sub('http\s+:\s+[/a-zA-Z0-9\.]+', ' ', clean_text)
    clean_text = re.sub('[w]{3}\.([A-Za-z0-9-]+)\.com', ' ', clean_text)
    clean_text = re.sub('RT', ' ', clean_text)
    clean_text = re.sub('yr old', ' ', clean_text)

    clean_text = clean_text.translate(translator)

    tagged_tokens = pos_tag([elem.lower() for elem in word_tokenize(clean_text)])

    tokens = [lemmatize(elem, lemmatizer) for elem in tagged_tokens]

    tokens = [elem for elem in tokens if elem not in english_stopwords]
    
    pattern_obj = re.compile('^[0-9].*$')
    return [elem for elem in tokens if pattern_obj.match(elem) is None]

def lemmatize(tagged_token,
              lemmatizer):

    if tagged_token[1].startswith('J'):
        pos = wordnet.ADJ
    elif tagged_token[1].startswith('V'):
        pos = wordnet.VERB
    elif tagged_token[1].startswith('N'):
        pos = wordnet.NOUN
    elif tagged_token[1].startswith('R'):
        pos = wordnet.ADV
    else:
        pos = None

    if pos is None:
        return lemmatizer.lemmatize(tagged_token[0])
    else:
        return lemmatizer.lemmatize(tagged_token[0], pos)

# %%
X_train, X_test, Y_train, Y_Test = train_test_split(X,
                                                    Y,
                                                    random_state=1011768029,
                                                    train_size=0.7)
# Out:
# /home/spmccar/anaconda3/envs/dsnano/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2069: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# ### 3. Build a machine learning pipeline
# - You'll find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
for idx in range(1000):
    print('----------------------------------------------------------')
    print(X_train[idx])
    print(tokenize(X_train[idx],
                   translator,
                   english_stopwords,
                   lemmatizer))
# Out:
# ----------------------------------------------------------
# Relief camps have been set up to house evacuated residents and tourists.
# ['relief', 'camp', 'set', 'house', 'evacuated', 'resident', 'tourist']
# ----------------------------------------------------------
# Please bring us help today, if you continue down siko ( ? ), in Carrefour, because we're dying of hunger
# ['please', 'bring', 'u', 'help', 'today', 'continue', 'siko', 'carrefour', 'die', 'hunger']
# ----------------------------------------------------------
# I would like to know your latest news
# ['would', 'like', 'know', 'late', 'news']
# ----------------------------------------------------------
# Dengue is characterized by a sudden onset of headaches, severe muscle and joint pains and often also a rash.
# ['dengue', 'characterize', 'sudden', 'onset', 'headache', 'severe', 'muscle', 'joint', 'pain', 'often', 'also', 'rash']
# ----------------------------------------------------------
# The ability to pick dengue from influenza is crucial, as dengue can progress into a more serious illness called Dengue Haemorrhagic Fever (DHF).
# ['ability', 'pick', 'dengue', 'influenza', 'crucial', 'dengue', 'progress', 'serious', 'illness', 'call', 'dengue', 'haemorrhagic', 'fever', 'dhf']
# ----------------------------------------------------------
# As temperatures plummeted last winter, rising demand for electricity to keep the population warm literally drained Toktogul of its resources.
# ['temperature', 'plummet', 'last', 'winter', 'rise', 'demand', 'electricity', 'keep', 'population', 'warm', 'literally', 'drain', 'toktogul', 'resource']
# ----------------------------------------------------------
# i have a problem talking to people in port au prince, please its talking to people god bless us
# ['problem', 'talk', 'people', 'port', 'au', 'prince', 'please', 'talk', 'people', 'god', 'bless', 'u']
# ----------------------------------------------------------
# This occurs at all levels from the individual and households through to national and regional economies.
# ['occur', 'level', 'individual', 'household', 'national', 'regional', 'economy']
# ----------------------------------------------------------
# The exact casualty figures from the train wreck have never been confirmed, but at least 1,500 died when the eight carriages and locomotive were tossed around like matchboxes
# ['exact', 'casualty', 'figure', 'train', 'wreck', 'never', 'confirm', 'least', 'die', 'eight', 'carriage', 'locomotive', 'toss', 'around', 'like', 'matchbox']
# ----------------------------------------------------------
# Satellite imagery indicates that rainfall amounts were well above the five-year average over the whole of Western Ethiopia during the first dekad of November while other parts of the country, especially Somali, east and South Oromia and parts of Afar received below normal rainfall.
# ['satellite', 'imagery', 'indicate', 'rainfall', 'amount', 'well', 'fiveyear', 'average', 'whole', 'western', 'ethiopia', 'first', 'dekad', 'november', 'part', 'country', 'especially', 'somali', 'east', 'south', 'oromia', 'part', 'afar', 'receive', 'normal', 'rainfall']
# ----------------------------------------------------------
# we are in Sarte, dead end Philadelphia. We have nothing left and we have no food.
# ['sarte', 'dead', 'end', 'philadelphia', 'nothing', 'leave', 'food']
# ----------------------------------------------------------
# 240,000 packets of water purifying powder are reaching 48,000 families.
# ['packet', 'water', 'purify', 'powder', 'reach', 'family']
# ----------------------------------------------------------
# Police baton-charged a group of Kosi flood victims and also fired into the air to take the unruly crowd into control after it stopped the police vehicle and started pelting stones at it.
# ['police', 'batoncharged', 'group', 'kosi', 'flood', 'victim', 'also', 'fire', 'air', 'take', 'unruly', 'crowd', 'control', 'stop', 'police', 'vehicle', 'start', 'pelt', 'stone']
# ----------------------------------------------------------
# These communities are in areas experiencing chronic food insecurity, environmental problems and a general lack of basic services. Therefore, training and retraining of the local counterparts leaders of groups and villages as well as the local staff at grassroots level is essential for sustainable implementation of the activities of the NGOs. It's a replica of an Ebola treatment unit (ETU), where doctors, nurses, hygienists, and others learn how to safely care for Ebola patients while staying alive. Logistics: A total of two access routes across hardened lava flows in the city of Goma have been opened by Agro Action Allemande (AAA), with funding from ECHO (OCHA Situation Report No.8 paragraph 6 refers). Samson Jeyakumar, World Vision's child protection specialist, said: Thousands of children are emotionally vulnerable and may be at risk of psychological trauma after witnessing unimaginable horrors such as losing loved ones and having to flee their homes.The initiative, aimed at drastically reducing the amount of time it takes to respond, awards grants of up to $10,000 to partner organizations in countries susceptible to natural disasters.
# ['community', 'area', 'experience', 'chronic', 'food', 'insecurity', 'environmental', 'problem', 'general', 'lack', 'basic', 'service', 'therefore', 'train', 'retrain', 'local', 'counterpart', 'leader', 'group', 'village', 'well', 'local', 'staff', 'grassroots', 'level', 'essential', 'sustainable', 'implementation', 'activity', 'ngo', 'replica', 'ebola', 'treatment', 'unit', 'etu', 'doctor', 'nurse', 'hygienist', 'others', 'learn', 'safely', 'care', 'ebola', 'patient', 'stay', 'alive', 'logistics', 'total', 'two', 'access', 'route', 'across', 'harden', 'lava', 'flow', 'city', 'goma', 'open', 'agro', 'action', 'allemande', 'aaa', 'funding', 'echo', 'ocha', 'situation', 'report', 'no8', 'paragraph', 'refers', 'samson', 'jeyakumar', 'world', 'vision', 'child', 'protection', 'specialist', 'say', 'thousand', 'child', 'emotionally', 'vulnerable', 'may', 'risk', 'psychological', 'trauma', 'witness', 'unimaginable', 'horror', 'lose', 'love', 'one', 'flee', 'homesthe', 'initiative', 'aim', 'drastically', 'reduce', 'amount', 'time', 'take', 'respond', 'award', 'grant', 'partner', 'organization', 'country', 'susceptible', 'natural', 'disaster']
# ----------------------------------------------------------
# I see bad news. We are under tents. Instead for food cost to decrease, it's increasing. What do you think we should do?
# ['see', 'bad', 'news', 'tent', 'instead', 'food', 'cost', 'decrease', 'increase', 'think']
# ----------------------------------------------------------
# I can help prepare food and distribute food , clean up , etc .
# ['help', 'prepare', 'food', 'distribute', 'food', 'clean', 'etc']
# ----------------------------------------------------------
# I would hope they give people who are thinking about all people without discrimination Thanks
# ['would', 'hope', 'give', 'people', 'think', 'people', 'without', 'discrimination', 'thanks']
# ----------------------------------------------------------
# medicine you did not visit ( bring ) we are counting on digicel.
# ['medicine', 'visit', 'bring', 'count', 'digicel']
# ----------------------------------------------------------
# Social workers are needed to help victims in Port-au-Prince, Gressier, Leogane, Petit-Goave,and Jacmel
# ['social', 'worker', 'need', 'help', 'victim', 'portauprince', 'gressier', 'leogane', 'petitgoaveand', 'jacmel']
# ----------------------------------------------------------
# How food aid would work out this week?
# ['food', 'aid', 'would', 'work', 'week']
# ----------------------------------------------------------
# The team previously tackled two other cholera epidemics (in Kamanyola and Uvira), a malaria emergency in Lulingo, and two measles emergencies, one in Kitutu and another in Bunyakiri, which included a vaccination campaign for 65,000 children.
# ['team', 'previously', 'tackle', 'two', 'cholera', 'epidemic', 'kamanyola', 'uvira', 'malaria', 'emergency', 'lulingo', 'two', 'measles', 'emergencies', 'one', 'kitutu', 'another', 'bunyakiri', 'include', 'vaccination', 'campaign', 'child']
# ----------------------------------------------------------
# SOUTH KOREA: Raises aid to $2 million, may send military cargo plane to move aid workers and supplies.
# ['south', 'korea', 'raise', 'aid', 'million', 'may', 'send', 'military', 'cargo', 'plane', 'move', 'aid', 'worker', 'supply']
# ----------------------------------------------------------
# Omg. Interception and touchdown #Giants up by 23. They are invading Dallas like #SandyIt's gona be fun taking my dog out to the bathroom during this hurricane #haha #cantwait #crazy #Sandy
# ['omg', 'interception', 'touchdown', 'giant', 'invade', 'dallas', 'like', 'sandyit', 'gona', 'fun', 'take', 'dog', 'bathroom', 'hurricane', 'haha', 'cantwait', 'crazy', 'sandy']
# ----------------------------------------------------------
# KARACHI, June 13 (AFP) - A bomb injured three people Wednesday as Pakistan's commercial hub of Karachi was paralysed by a protest strike following a night of anti-government violence in which two people died.
# ['karachi', 'june', 'afp', 'bomb', 'injure', 'three', 'people', 'wednesday', 'pakistan', 'commercial', 'hub', 'karachi', 'paralyse', 'protest', 'strike', 'follow', 'night', 'antigovernment', 'violence', 'two', 'people', 'die']
# ----------------------------------------------------------
# Could we get a tarp - a tent would be even better - because I have my mother and one her arms ? is paralyzed -- she is still not doing well -- if possible please find a way to emessage cut off
# ['could', 'get', 'tarp', 'tent', 'would', 'even', 'well', 'mother', 'one', 'arm', 'paralyzed', 'still', 'well', 'possible', 'please', 'find', 'way', 'emessage', 'cut']
# ----------------------------------------------------------
# (a) WFP has completed its first distribution of food to families that suffered crop losses due to the drought.
# ['wfp', 'complete', 'first', 'distribution', 'food', 'family', 'suffer', 'crop', 'loss', 'due', 'drought']
# ----------------------------------------------------------
# The volunteers are using ARCHI to ol kits as information, education and communication (IEC) materials in conductin g hygiene promotion campaigns through community meetings during distribution of relief items.Associate professor Dr. Charlie Jaroenlapnopparat of Thammasart University said the gymnasium had been turned into a temporary shelter for flood evacuees which could accommodate up to 1,300 people.
# ['volunteer', 'use', 'archi', 'ol', 'kit', 'information', 'education', 'communication', 'iec', 'material', 'conductin', 'g', 'hygiene', 'promotion', 'campaign', 'community', 'meeting', 'distribution', 'relief', 'itemsassociate', 'professor', 'dr', 'charlie', 'jaroenlapnopparat', 'thammasart', 'university', 'say', 'gymnasium', 'turn', 'temporary', 'shelter', 'flood', 'evacuee', 'could', 'accommodate', 'people']
# ----------------------------------------------------------
# I am 28yr old I have some journalism/comunication experience, where can I go and drop my CV for a job please
# ['journalismcomunication', 'experience', 'go', 'drop', 'cv', 'job', 'please']
# ----------------------------------------------------------
# Thick smog blanketing Sumatra and Kalimantan triggered a shutdown of seven airports in Indonesia on Sunday.
# ['thick', 'smog', 'blanket', 'sumatra', 'kalimantan', 'trigger', 'shutdown', 'seven', 'airport', 'indonesia', 'sunday']
# ----------------------------------------------------------
# working to take care of my children and my wife it's you can I ask cause I am suffering so much, my childen suffer for food thank you
# ['work', 'take', 'care', 'child', 'wife', 'ask', 'suffer', 'much', 'childen', 'suffer', 'food', 'thank']
# ----------------------------------------------------------
# Information of earthquake that occured january 12
# ['information', 'earthquake', 'occur', 'january']
# ----------------------------------------------------------
# We used whatever medicinal supplies we had to treat as many sick people as we could until we run out of drugs.
# ['use', 'whatever', 'medicinal', 'supply', 'treat', 'many', 'sick', 'people', 'could', 'run', 'drug']
# ----------------------------------------------------------
# Capt. Obbo said the army has distributed improved cassava cuttings worth Shs5 million to reformed Karimojong warriors in Nakapiripirit and Moroto districts.
# ['capt', 'obbo', 'say', 'army', 'distribute', 'improve', 'cassava', 'cutting', 'worth', 'shs5', 'million', 'reform', 'karimojong', 'warrior', 'nakapiripirit', 'moroto', 'district']
# ----------------------------------------------------------
# Five law lords in London ruled that the miners, who claim to be suffering asbestos-related diseases, would be denied justice if they were prevented from suing their former employer, UK-based Cape Plc, in Britain instead of South Africa.
# ['five', 'law', 'lord', 'london', 'rule', 'miner', 'claim', 'suffer', 'asbestosrelated', 'disease', 'would', 'deny', 'justice', 'prevent', 'sue', 'former', 'employer', 'ukbased', 'cape', 'plc', 'britain', 'instead', 'south', 'africa']
# ----------------------------------------------------------
# Additional water was injected via the Spent Fuel Cooling System line to the spent fuel pool by a temporary pump on 4th April.
# ['additional', 'water', 'inject', 'via', 'spent', 'fuel', 'cool', 'system', 'line', 'spent', 'fuel', 'pool', 'temporary', 'pump', 'april']
# ----------------------------------------------------------
# RT ASA: RT @Astro_Soichi: http://twitpic.com/18deq7 - Concepcion, Chile. Three weeks after the earthquake.
# ['asa', 'astrosoichi', 'concepcion', 'chile', 'three', 'week', 'earthquake']
# ----------------------------------------------------------
# I am a person needing help in Delma 18. I'm sleeping in the street, we haven't found anything in ways of help
# ['person', 'need', 'help', 'delma', 'sleep', 'street', 'find', 'anything', 'way', 'help']
# ----------------------------------------------------------
# we are living in fafan zone alley ray in kafou we never find something like family tent, food we are 200 person in the shelter.
# ['live', 'fafan', 'zone', 'alley', 'ray', 'kafou', 'never', 'find', 'something', 'like', 'family', 'tent', 'food', 'person', 'shelter']
# ----------------------------------------------------------
# At the request of BMG, the response has involved the provision (on an in-kind basis) of equipment, including: two laptop computers, a desktop computer, an "all-in-one" printer/scanner/fax/copier, a UPS, and a back-up/auto-start generator to maintain operation of the seismograph during Banda Aceh's frequent power outages.
# ['request', 'bmg', 'response', 'involve', 'provision', 'inkind', 'basis', 'equipment', 'include', 'two', 'laptop', 'computer', 'desktop', 'computer', 'allinone', 'printerscannerfaxcopier', 'ups', 'backupautostart', 'generator', 'maintain', 'operation', 'seismograph', 'banda', 'acehs', 'frequent', 'power', 'outage']
# ----------------------------------------------------------
# In neighbouring Thailand, unusually heavy rain has caused the worst flooding in decades.
# ['neighbour', 'thailand', 'unusually', 'heavy', 'rain', 'cause', 'bad', 'flooding', 'decade']
# ----------------------------------------------------------
# Several thousand internally displaced persons (IDPs) have been identified in the southern part of the region and in neighboring counties of Bahr-el-Ghazal and Lakes Regions.
# ['several', 'thousand', 'internally', 'displaced', 'person', 'idps', 'identify', 'southern', 'part', 'region', 'neighbor', 'county', 'bahrelghazal', 'lake', 'region']
# ----------------------------------------------------------
# I have several items I can donate including : -a bassinet stroller -half a packet of preemie diapers -candles -paper towels -9volt batteries -size 14/16 maternity jeans -canned tuna and shrimp
# ['several', 'item', 'donate', 'include', 'bassinet', 'stroller', 'half', 'packet', 'preemie', 'diaper', 'candle', 'paper', 'towel', 'battery', 'size', 'maternity', 'jean', 'tuna', 'shrimp']
# ----------------------------------------------------------
# Since after this earthquake I was feelingfaint,I can't to eat, i can't to sleep in my hourse at port-au-prince.
# ['since', 'earthquake', 'feelingfainti', 'eat', 'sleep', 'hourse', 'portauprince']
# ----------------------------------------------------------
# Twin suicide blasts on Sunday killed at least nine people in far northern Cameroon, a day after triple explosions in Chad left 41 dead, in a weekend of violence blamed on Boko Haram Islamists.
# ['twin', 'suicide', 'blast', 'sunday', 'kill', 'least', 'nine', 'people', 'far', 'northern', 'cameroon', 'day', 'triple', 'explosion', 'chad', 'leave', 'dead', 'weekend', 'violence', 'blame', 'boko', 'haram', 'islamist']
# ----------------------------------------------------------
# I would like to know what's new with them. Or the latest news about them.
# ['would', 'like', 'know', 'new', 'late', 'news']
# ----------------------------------------------------------
# I heard that you are accepting prepared food . I am happy to cook and bring food .
# ['hear', 'accept', 'prepared', 'food', 'happy', 'cook', 'bring', 'food']
# ----------------------------------------------------------
# In Killinochchi Oxfam will start a campaign to get public support to construct compost toilets in villages.
# ['killinochchi', 'oxfam', 'start', 'campaign', 'get', 'public', 'support', 'construct', 'compost', 'toilet', 'village']
# ----------------------------------------------------------
# The yellow root color of the vitamin A-rich varieties are products of over 20 years of breeding efforts for improved nutritional quality using traditional breeding methods involving hybridization and selection of cassava seedlings followed by clonal propagation of the selected desirable plants.
# ['yellow', 'root', 'color', 'vitamin', 'arich', 'variety', 'product', 'year', 'breed', 'effort', 'improved', 'nutritional', 'quality', 'use', 'traditional', 'breeding', 'method', 'involve', 'hybridization', 'selection', 'cassava', 'seedling', 'follow', 'clonal', 'propagation', 'select', 'desirable', 'plant']
# ----------------------------------------------------------
# Police and military officials are going door-to-door to enforce a mandatory evacuation order.
# ['police', 'military', 'official', 'go', 'doortodoor', 'enforce', 'mandatory', 'evacuation', 'order']
# ----------------------------------------------------------
# This is the second time in four months that Tanzania was caught napping by disasters after more than 200 people died in September after a ferry sunk off the coast of Nungwi village, leaving Tanzania battling its worst maritime disaster in 15 years.
# ['second', 'time', 'four', 'month', 'tanzania', 'catch', 'nap', 'disaster', 'people', 'die', 'september', 'ferry', 'sunk', 'coast', 'nungwi', 'village', 'leave', 'tanzania', 'battle', 'bad', 'maritime', 'disaster', 'year']
# ----------------------------------------------------------
# ickJsOrgasm i think the 50% of the people in concepcion died :S , the bodys are in the streets im from chile :/
# ['ickjsorgasm', 'think', 'people', 'concepcion', 'die', 'body', 'street', 'im', 'chile']
# ----------------------------------------------------------
# 7News Haiti earthquake story http ow.ly VVwh &lt incl news vid & image gallery.Brisbane woman missing is rachelhoffman
# ['haiti', 'earthquake', 'story', 'rachelhoffman']
# ----------------------------------------------------------
# It is in line with regional agricultural policy guidelines, particularly: (i) CILSS' Food Security Strategic Framework (FSSF) to fight poverty; (ii) the West African Economic and Monetary Union (WAEMU) Agricultural Policy (WAP); and (iii) the ECOWAS Agricultural Policy (ECOWAP).
# ['line', 'regional', 'agricultural', 'policy', 'guideline', 'particularly', 'cilss', 'food', 'security', 'strategic', 'framework', 'fssf', 'fight', 'poverty', 'ii', 'west', 'african', 'economic', 'monetary', 'union', 'waemu', 'agricultural', 'policy', 'wap', 'iii', 'ecowas', 'agricultural', 'policy', 'ecowap']
# ----------------------------------------------------------
# (b) Areas under control of the Forces Nouvelles remain tense with reports of imminent attacks and an increased recruitment of soldiers.
# ['b', 'area', 'control', 'force', 'nouvelles', 'remain', 'tense', 'report', 'imminent', 'attack', 'increased', 'recruitment', 'soldier']
# ----------------------------------------------------------
# there is a house in Brochet 47 near the school. It's a danger its about to collapse.
# ['house', 'brochet', 'near', 'school', 'danger', 'collapse']
# ----------------------------------------------------------
# Please rescue Valliant. Help us, even if it's at night. Lots of mosquitos eating us up. Even come in the evening. We need electricity
# ['please', 'rescue', 'valliant', 'help', 'u', 'even', 'night', 'lot', 'mosquito', 'eat', 'u', 'even', 'come', 'evening', 'need', 'electricity']
# ----------------------------------------------------------
# Operation Goal: to meet the urgent needs of the 50,000 worst affected families in Assam and Bihar with food, shelter, family packs and medical services, to ensure improved quality of water over a period of four months and prepare to meet longer-term needs through necessary capacity building and disaster mitigation initiatives over a further period of six months after the emergency phase.
# ['operation', 'goal', 'meet', 'urgent', 'need', 'bad', 'affected', 'family', 'assam', 'bihar', 'food', 'shelter', 'family', 'pack', 'medical', 'service', 'ensure', 'improved', 'quality', 'water', 'period', 'four', 'month', 'prepare', 'meet', 'longerterm', 'need', 'necessary', 'capacity', 'building', 'disaster', 'mitigation', 'initiatives', 'period', 'six', 'month', 'emergency', 'phase']
# ----------------------------------------------------------
# A similar operation would foster the agricultural development of the populations residing near to the Wadi Shebele, thereby helping improve their food situation.
# ['similar', 'operation', 'would', 'foster', 'agricultural', 'development', 'population', 'reside', 'near', 'wadi', 'shebele', 'thereby', 'help', 'improve', 'food', 'situation']
# ----------------------------------------------------------
# Reading some reports about the earthquake in Haiti.
# ['read', 'report', 'earthquake', 'haiti']
# ----------------------------------------------------------
# I have not found a phone or aid. Send us something because we are not well at all
# ['find', 'phone', 'aid', 'send', 'u', 'something', 'well']
# ----------------------------------------------------------
# Nebraskans with ties to Haiti hold breath on news of earthquake ! cousin http bit.ly 54I4dH
# ['nebraskan', 'tie', 'haiti', 'hold', 'breath', 'news', 'earthquake', 'cousin']
# ----------------------------------------------------------
# Information requiere about of the earthquake.
# ['information', 'requiere', 'earthquake']
# ----------------------------------------------------------
# MBE. WE ARE ALMOST WITHOUT WATER TO DRINK. PLEASE STOP BY ON RUE SAINTILUS ( SAINTILUS STREET ) OK
# ['mbe', 'almost', 'without', 'water', 'drink', 'please', 'stop', 'rue', 'saintilus', 'saintilus', 'street', 'ok']
# ----------------------------------------------------------
# MUZAFFARABAD, Mar.7 (APP): AJK Prime Minister Sardar Sikandar Hayyat Khan on Tuesday said that reconstruction phase would start in April saying around Rs 80 billion would be spent on reconstruction works in the quake-hit areas of AJK.
# ['muzaffarabad', 'mar7', 'app', 'ajk', 'prime', 'minister', 'sardar', 'sikandar', 'hayyat', 'khan', 'tuesday', 'say', 'reconstruction', 'phase', 'would', 'start', 'april', 'say', 'around', 'r', 'billion', 'would', 'spend', 'reconstruction', 'work', 'quakehit', 'area', 'ajk']
# ----------------------------------------------------------
# If we want them to go back home, we've got to carry out food distribution programs, build water systems, and rehabilitate farms and housing in the wake of the bombing-all factors that will contribute to pulling them back home."
# ['want', 'go', 'back', 'home', 'get', 'carry', 'food', 'distribution', 'program', 'build', 'water', 'system', 'rehabilitate', 'farm', 'housing', 'wake', 'bombingall', 'factor', 'contribute', 'pull', 'back', 'home']
# ----------------------------------------------------------
# With the constitution of year 86 country of Haiti knew 23 constitutions
# ['constitution', 'year', 'country', 'haiti', 'know', 'constitution']
# ----------------------------------------------------------
# As for food, a balanced food basket in addition to rice and noodles and food for babies and children are needed.
# ['food', 'balance', 'food', 'basket', 'addition', 'rice', 'noodle', 'food', 'baby', 'child', 'need']
# ----------------------------------------------------------
# Women were consulted in the design of water collection points and public water distribution stations and they were also recruited to supervise and administer water distribution from fixed water tanks.
# ['woman', 'consult', 'design', 'water', 'collection', 'point', 'public', 'water', 'distribution', 'station', 'also', 'recruit', 'supervise', 'administer', 'water', 'distribution', 'fixed', 'water', 'tank']
# ----------------------------------------------------------
# The national archive is it functional?
# ['national', 'archive', 'functional']
# ----------------------------------------------------------
# .. in math. I'd like to be informed of any available job offers
# ['math', 'would', 'like', 'inform', 'available', 'job', 'offer']
# ----------------------------------------------------------
# (f) In Katanga, as a result of food insecurity prevailing in Malemba-Nkulu, the UN Office for the Coordination of Humanitarian Affairs (OCHA) approached WFP to extend food assistance to some remote villages.
# ['f', 'katanga', 'result', 'food', 'insecurity', 'prevailing', 'malembankulu', 'un', 'office', 'coordination', 'humanitarian', 'affair', 'ocha', 'approach', 'wfp', 'extend', 'food', 'assistance', 'remote', 'village']
# ----------------------------------------------------------
# Two weeks ago, truck convoys carrying WFP food were attacked in Zabul and Nimroz provinces resulting in the killing of a driver and an escort.
# ['two', 'week', 'ago', 'truck', 'convoy', 'carry', 'wfp', 'food', 'attack', 'zabul', 'nimroz', 'province', 'result', 'killing', 'driver', 'escort']
# ----------------------------------------------------------
# NGOs fear being targeted as violence escalates
# ['ngo', 'fear', 'target', 'violence', 'escalates']
# ----------------------------------------------------------
# How is the activities in the camps?
# ['activity', 'camp']
# ----------------------------------------------------------
# It warned that the destruction of branch pipes across the street was bound to worsen inner city flooding on rainy days and more places would be vulnerable to heavy inundation.Sialkot District, about 120km northeast of Lahore, saw torrential rain on 6 August: Drains almost immediately overflowed, villages were inundated, agricultural land damaged and residents left stranded as water surrounded homes.
# ['warn', 'destruction', 'branch', 'pipe', 'across', 'street', 'bind', 'worsen', 'inner', 'city', 'flooding', 'rainy', 'day', 'place', 'would', 'vulnerable', 'heavy', 'inundationsialkot', 'district', 'northeast', 'lahore', 'saw', 'torrential', 'rain', 'august', 'drain', 'almost', 'immediately', 'overflowed', 'village', 'inundate', 'agricultural', 'land', 'damage', 'resident', 'leave', 'strand', 'water', 'surround', 'home']
# ----------------------------------------------------------
# Closer to the coast, however, saturated soil conditions and river levels near full capacity may lead to flooding given any moderate precipitation events.
# ['closer', 'coast', 'however', 'saturate', 'soil', 'condition', 'river', 'level', 'near', 'full', 'capacity', 'may', 'lead', 'flood', 'give', 'moderate', 'precipitation', 'event']
# ----------------------------------------------------------
# To learn more or to make a donation, visit www.thrivent.com, or call 1-800-LWR-LWR-2.
# ['learn', 'make', 'donation', 'visit', 'call']
# ----------------------------------------------------------
# Hi, all the international organizations.thans, for the donetion to give in Haiti.even, there are family have nothing.
# ['hi', 'international', 'organizationsthans', 'donetion', 'give', 'haitieven', 'family', 'nothing']
# ----------------------------------------------------------
# Good afternoon, how the situation was for the day
# ['good', 'afternoon', 'situation', 'day']
# ----------------------------------------------------------
# Some 3,000 US marines and navy personnel have arrived on the coast of Kenya for a series of joint military exercises to be carried out in collaboration with Kenyan servicemen in the coastal region.
# ['u', 'marine', 'navy', 'personnel', 'arrive', 'coast', 'kenya', 'series', 'joint', 'military', 'exercise', 'carry', 'collaboration', 'kenyan', 'serviceman', 'coastal', 'region']
# ----------------------------------------------------------
# Army and paramilitary personnel have been deployed to reach those trapped but bad weather prevented rescue helicopters from lifting those stranded in many places.
# ['army', 'paramilitary', 'personnel', 'deploy', 'reach', 'trap', 'bad', 'weather', 'prevent', 'rescue', 'helicopter', 'lift', 'strand', 'many', 'place']
# ----------------------------------------------------------
# WHO recommends that the Government take immediate action to reduce the risk of dengue transmission and mitigate the impact of the dengue epidemic.
# ['recommend', 'government', 'take', 'immediate', 'action', 'reduce', 'risk', 'dengue', 'transmission', 'mitigate', 'impact', 'dengue', 'epidemic']
# ----------------------------------------------------------
# These were buying firefighting and telecommunications equipment and a setting up a detection system, which would include spare parts and fuel for spotter planes and helicopters grounded due to lack of money.
# ['buy', 'firefighting', 'telecommunication', 'equipment', 'set', 'detection', 'system', 'would', 'include', 'spare', 'part', 'fuel', 'spotter', 'plane', 'helicopter', 'ground', 'due', 'lack', 'money']
# ----------------------------------------------------------
# The national and provincial parliaments should oversee these efforts, including maintaining accountability over donor and government funds through their public accounts committees.
# ['national', 'provincial', 'parliament', 'oversee', 'effort', 'include', 'maintain', 'accountability', 'donor', 'government', 'fund', 'public', 'account', 'committee']
# ----------------------------------------------------------
# Other well-meaning groups gave fishermen boats that were not designed to the specific dimensions of longtail boats traditionally used here, while others were built with illegally cut timber, aid officials said.
# ['wellmeaning', 'group', 'give', 'fisherman', 'boat', 'design', 'specific', 'dimension', 'longtail', 'boat', 'traditionally', 'use', 'others', 'build', 'illegally', 'cut', 'timber', 'aid', 'official', 'say']
# ----------------------------------------------------------
# Incessant rain since Sunday night has left hundreds of Indian and Nepali pilgrims stranded at the temple, he added.
# ['incessant', 'rain', 'since', 'sunday', 'night', 'leave', 'hundred', 'indian', 'nepali', 'pilgrim', 'strand', 'temple', 'add']
# ----------------------------------------------------------
# I need help in Jrmie because I was in Port-au-Prince in university I am counting on you.
# ['need', 'help', 'jrmie', 'portauprince', 'university', 'count']
# ----------------------------------------------------------
# The ICRC is one of the few organizations working in these remoter areas.
# ['icrc', 'one', 'organization', 'work', 'remoter', 'area']
# ----------------------------------------------------------
# is unit and the respect!!! HAITI is us! Us is HAITI!!!
# ['unit', 'respect', 'haiti', 'u', 'u', 'haiti']
# ----------------------------------------------------------
# The technical evidence obtained from remote-sensing (e.g. satellite photography) and other sources shows that flooding of the scale in Spring 2007 is very unlikely, because this is a function of the thickness of the snowpack, the suddenness of the rise in temperature, and often also rain which speeds up the melting and run-off process.
# ['technical', 'evidence', 'obtain', 'remotesensing', 'eg', 'satellite', 'photography', 'source', 'show', 'flood', 'scale', 'spring', 'unlikely', 'function', 'thickness', 'snowpack', 'suddenness', 'rise', 'temperature', 'often', 'also', 'rain', 'speed', 'melting', 'runoff', 'process']
# ----------------------------------------------------------
# Water and Sanitation - Installation of ecosan toilets was completed in Barabanki and progress was made in Bahraich districts.
# ['water', 'sanitation', 'installation', 'ecosan', 'toilet', 'complete', 'barabanki', 'progress', 'make', 'bahraich', 'district']
# ----------------------------------------------------------
# Workers are also preparing to purchase large quantities of tin in order to repair some of the hundreds of homes damaged by the storms.
# ['worker', 'also', 'prepare', 'purchase', 'large', 'quantity', 'tin', 'order', 'repair', 'hundred', 'home', 'damage', 'storm']
# ----------------------------------------------------------
# We thinkg that security wants to stay only in Port au Prince because stealers want to kill us in this province
# ['thinkg', 'security', 'want', 'stay', 'port', 'au', 'prince', 'stealer', 'want', 'kill', 'u', 'province']
# ----------------------------------------------------------
# Do hurricane and earthquake, announce to Haiti?
# ['hurricane', 'earthquake', 'announce', 'haiti']
# ----------------------------------------------------------
# The Chinese government has developed policies to improve energy efficiency and pollution control in the cement sector.
# ['chinese', 'government', 'develop', 'policy', 'improve', 'energy', 'efficiency', 'pollution', 'control', 'cement', 'sector']
# ----------------------------------------------------------
# Good Evening Digicel. We are here in the second level of the Church of Saint Maire. We have yet to receive anything besides water. What can you do to help us, please?
# ['good', 'evening', 'digicel', 'second', 'level', 'church', 'saint', 'maire', 'yet', 'receive', 'anything', 'besides', 'water', 'help', 'u', 'please']
# ----------------------------------------------------------
# The only place in Danan where there is activity is among a cluster of low red mounds beside the refugee shelters: the burial ground.
# ['place', 'danan', 'activity', 'among', 'cluster', 'low', 'red', 'mound', 'beside', 'refugee', 'shelter', 'burial', 'ground']
# ----------------------------------------------------------
# Reports of another storm heading towards Myanmar today underscored the urgency of the situation.
# ['report', 'another', 'storm', 'heading', 'towards', 'myanmar', 'today', 'underscore', 'urgency', 'situation']
# ----------------------------------------------------------
# Funds have also been released from our disaster relief emergency fund to support awareness raising activities in neighbouring countries of Liberia, Sierra Leone and Senegal.
# ['fund', 'also', 'release', 'disaster', 'relief', 'emergency', 'fund', 'support', 'awareness', 'raise', 'activity', 'neighbour', 'country', 'liberia', 'sierra', 'leone', 'senegal']
# ----------------------------------------------------------
# Heavy mudslides triggered by incessant rain have severed rail links connecting Tripura and Assam states to the rest of India, officials said.
# ['heavy', 'mudslide', 'trigger', 'incessant', 'rain', 'sever', 'rail', 'link', 'connect', 'tripura', 'assam', 'state', 'rest', 'india', 'official', 'say']
# ----------------------------------------------------------
# .. dark, and the mosquitoes are eating us. Please send an institution to do something for us. My pole number is DAS 052
# ['dark', 'mosquito', 'eat', 'u', 'please', 'send', 'institution', 'something', 'u', 'pole', 'number', 'das']
# ----------------------------------------------------------
# f k yo ap mal viv nan ansagal lagonav.msi.
# ['f', 'k', 'yo', 'ap', 'mal', 'viv', 'nan', 'ansagal', 'lagonavmsi']
# ----------------------------------------------------------
# I thank you United Nations for the advices unfortunately I don't find the shelter yet. I already wrote you but I didn't find any answer.I need tent.
# ['thank', 'united', 'nation', 'advice', 'unfortunately', 'find', 'shelter', 'yet', 'already', 'write', 'find', 'answeri', 'need', 'tent']
# ----------------------------------------------------------
# You will move the people that are lodged to the champ-de-mars. in other which place you will put them?
# ['move', 'people', 'lodge', 'champdemars', 'place', 'put']
# ----------------------------------------------------------
# what's about the MMS. how is fonctioning?
# ['mm', 'fonctioning']
# ----------------------------------------------------------
# I and my family (16 persons) in 3e comunal section TiBoukan, Gressier, we never find any food, anything.
# ['family', 'person', 'comunal', 'section', 'tiboukan', 'gressier', 'never', 'find', 'food', 'anything']
# ----------------------------------------------------------
# thoses money won't sink like the other 197 billions, this time, the country must take the road of development thankyou
# ['tho', 'money', 'sink', 'like', 'billion', 'time', 'country', 'must', 'take', 'road', 'development', 'thankyou']
# ----------------------------------------------------------
# SRINAGAR, India, Nov 8 (AFP) - A leading separatist leader, angered at the teargassing of earthquake survivors as they surged towards the Kashmir frontier, called Tuesday on India and Pakistan to ease travel restrictions on Kashmiris.
# ['srinagar', 'india', 'nov', 'afp', 'leading', 'separatist', 'leader', 'anger', 'teargassing', 'earthquake', 'survivor', 'surge', 'towards', 'kashmir', 'frontier', 'call', 'tuesday', 'india', 'pakistan', 'ease', 'travel', 'restriction', 'kashmiri']
# ----------------------------------------------------------
# The Fiji Rugby Union also handed over the $15,000 donation that was collected as part of the charity auction held in Nadi recently.
# ['fiji', 'rugby', 'union', 'also', 'hand', 'donation', 'collect', 'part', 'charity', 'auction', 'hold', 'nadi', 'recently']
# ----------------------------------------------------------
# A cargo aircraft landed in Mombasa on 13 August, carrying 50 metric tons of high-nutrient Plumpy 'Sup, enough to feed almost 16,500 malnourished children under age five for a month.
# ['cargo', 'aircraft', 'land', 'mombasa', 'august', 'carry', 'metric', 'ton', 'highnutrient', 'plumpy', 'sup', 'enough', 'fee', 'almost', 'malnourished', 'child', 'age', 'five', 'month']
# ----------------------------------------------------------
# NOTES: This message is not important because the author is kidding.
# ['note', 'message', 'important', 'author', 'kid']
# ----------------------------------------------------------
# 'Do you think that they can find again some people alive under' the rubble?
# ['wouldo', 'think', 'find', 'people', 'alive', 'rubble']
# ----------------------------------------------------------
# Mehar surrounded by flood water
# ['mehar', 'surround', 'flood', 'water']
# ----------------------------------------------------------
# If a refugee has not received any aid, where can they go. We have 1000 people in Delmas 41 across from the Teleco.
# ['refugee', 'receive', 'aid', 'go', 'people', 'delmas', 'across', 'teleco']
# ----------------------------------------------------------
# i need help i can't stay here anymore
# ['need', 'help', 'stay', 'anymore']
# ----------------------------------------------------------
# u know I cannot leave papy thank u
# ['know', 'leave', 'papy', 'thank']
# ----------------------------------------------------------
# A second planeload of biscuits is due to leave Brindisi on Friday and in the meantime 40 tons of dates, donated by Qatar, are being transported from Quetta, in the west of Pakistan.
# ['second', 'planeload', 'biscuit', 'due', 'leave', 'brindisi', 'friday', 'meantime', 'ton', 'date', 'donate', 'qatar', 'transport', 'quetta', 'west', 'pakistan']
# ----------------------------------------------------------
# RT SAMMIESMILES8 RT pinkelephantpun Earthquake Relief Donate http bit.ly 67t0d0 Select Immediate Needs to help those affected ..
# ['sammiesmiles8', 'pinkelephantpun', 'earthquake', 'relief', 'donate', 'select', 'immediate', 'need', 'help', 'affected']
# ----------------------------------------------------------
# He then explained plans and funding arrangements now in place for infrastructure reconstruction in the affected sectors.
# ['explain', 'plan', 'fund', 'arrangement', 'place', 'infrastructure', 'reconstruction', 'affected', 'sector']
# ----------------------------------------------------------
# what the highest most laborious summits. (Fr Donel)
# ['high', 'laborious', 'summit', 'fr', 'donel']
# ----------------------------------------------------------
# Direct Relief is in contact with its corporate partners and is poised to provide medical material assistance if requested.
# ['direct', 'relief', 'contact', 'corporate', 'partner', 'poise', 'provide', 'medical', 'material', 'assistance', 'request']
# ----------------------------------------------------------
# CRS and its partners have responded by opening two feeding centers in town and by providing urgently needed medical supplies, equipment and other support for the hospital and accessible health centers, an intervention funded by USAID's Office of Foreign Disaster Assistance.
# ['cr', 'partner', 'respond', 'open', 'two', 'feeding', 'center', 'town', 'provide', 'urgently', 'need', 'medical', 'supply', 'equipment', 'support', 'hospital', 'accessible', 'health', 'center', 'intervention', 'fund', 'usaids', 'office', 'foreign', 'disaster', 'assistance']
# ----------------------------------------------------------
# I already did this. Its saying the Digicel (A cell phone?) is out of power or minutes.
# ['already', 'say', 'digicel', 'cell', 'phone', 'power', 'minute']
# ----------------------------------------------------------
# it would be better for me if you would call me
# ['would', 'good', 'would', 'call']
# ----------------------------------------------------------
# One -- a floating hospital -- would be docking in Aceh on January 2, while the second carrying relief supplies -- tents, blankets, emergency rations and emergency medical supplies -- was leaving the southern port of Madras Friday.
# ['one', 'floating', 'hospital', 'would', 'dock', 'aceh', 'january', 'second', 'carrying', 'relief', 'supply', 'tent', 'blanket', 'emergency', 'ration', 'emergency', 'medical', 'supply', 'leave', 'southern', 'port', 'madras', 'friday']
# ----------------------------------------------------------
# ikePortnoyDT can you confirm what day are DT performing santiago? the fans are not sure if it changed to the 12th or remains on the 11th
# ['ikeportnoydt', 'confirm', 'day', 'dt', 'perform', 'santiago', 'fan', 'sure', 'change', 'remains']
# ----------------------------------------------------------
# We ar in the Morija Adventis Church in Dikini, we need water, food and tents.
# ['ar', 'morija', 'adventis', 'church', 'dikini', 'need', 'water', 'food', 'tent']
# ----------------------------------------------------------
# We want to reach a stage where robust yam seed production techniques will use parts of the yam plant other than tubers, thereby releasing an additional 30 percent of the crop to food ware tubers."
# ['want', 'reach', 'stage', 'robust', 'yam', 'seed', 'production', 'technique', 'use', 'part', 'yam', 'plant', 'tuber', 'thereby', 'release', 'additional', 'percent', 'crop', 'food', 'ware', 'tuber']
# ----------------------------------------------------------
# FEniveL first 7.2 second 6.9 third 6.0 in the epicenter .so close of santiago!
# ['fenivel', 'first', 'second', 'third', 'epicenter', 'close', 'santiago']
# ----------------------------------------------------------
# I would like to receive information on everything.
# ['would', 'like', 'receive', 'information', 'everything']
# ----------------------------------------------------------
# Staff of the Tajik National Hydromet Service are full participants in the regional snowmelt runoff committee that meets semi-annually to improve water allocations for the Central Asia region.
# ['staff', 'tajik', 'national', 'hydromet', 'service', 'full', 'participant', 'regional', 'snowmelt', 'runoff', 'committee', 'meet', 'semiannually', 'improve', 'water', 'allocation', 'central', 'asia', 'region']
# ----------------------------------------------------------
# Many lost their homes when the huge waves swept ashore on March 11, killing 20,000 people and grinding whole neighbourhoods into matchwood.
# ['many', 'lose', 'home', 'huge', 'wave', 'sweep', 'ashore', 'march', 'kill', 'people', 'grind', 'whole', 'neighbourhood', 'matchwood']
# ----------------------------------------------------------
# Too many boats, sails and nets were destroyed in the tsunami disaster, and the horrific memories are still all too present.
# ['many', 'boat', 'sail', 'net', 'destroy', 'tsunami', 'disaster', 'horrific', 'memory', 'still', 'present']
# ----------------------------------------------------------
# I NEVER FOUND ANY HELP SINCE THE QUAKE CAN I FIND AT LEAST A JOB?
# ['never', 'find', 'help', 'since', 'quake', 'find', 'least', 'job']
# ----------------------------------------------------------
# I see that you really forget me, but this fire which in my heart for you will stay forever.
# ['see', 'really', 'forget', 'fire', 'heart', 'stay', 'forever']
# ----------------------------------------------------------
# Tomorrow I will be in malibu nightclub. The ocean view hotel of nagasaki and hiroshima and an hold site.
# ['tomorrow', 'malibu', 'nightclub', 'ocean', 'view', 'hotel', 'nagasaki', 'hiroshima', 'hold', 'site']
# ----------------------------------------------------------
# NOTES: I had already translated this message.
# ['note', 'already', 'translate', 'message']
# ----------------------------------------------------------
# near about 50 houses of basti jam gulab pahore and basti ghulam haidar pahore have been destroyed in the recent flood but no compensation has been provided till date. we have just received one quilt from chief minister of punjab, winter is making children sick.
# ['near', 'house', 'basti', 'jam', 'gulab', 'pahore', 'basti', 'ghulam', 'haidar', 'pahore', 'destroy', 'recent', 'flood', 'compensation', 'provide', 'till', 'date', 'receive', 'one', 'quilt', 'chief', 'minister', 'punjab', 'winter', 'make', 'child', 'sick']
# ----------------------------------------------------------
# @Mikefavetta .. it 's getting very wet out here ! .. bringing it ! .. surfs up #sandy #Fra @The Bruno Compound http : //t.co/YNenUCKe
# ['mikefavetta', 'get', 'wet', 'bring', 'surf', 'sandy', 'fra', 'bruno', 'compound']
# ----------------------------------------------------------
# The agency provides assistance to people in more than 100 countries and territories based on need, regardless of race, nationality or creed.
# ['agency', 'provide', 'assistance', 'people', 'country', 'territory', 'base', 'need', 'regardless', 'race', 'nationality', 'creed']
# ----------------------------------------------------------
# I live with six persons, we would like to find tent, Food, dlo, Thanks a lot.
# ['live', 'six', 'person', 'would', 'like', 'find', 'tent', 'food', 'dlo', 'thank', 'lot']
# ----------------------------------------------------------
# IMC has helped thwart outbreaks of measles epidemics in both the Ghari Habibullah and Bessian camps by successfully immunizing 92% of the vulnerable populations in both camps.
# ['imc', 'help', 'thwart', 'outbreak', 'measles', 'epidemic', 'ghari', 'habibullah', 'bessian', 'camp', 'successfully', 'immunize', 'vulnerable', 'population', 'camp']
# ----------------------------------------------------------
# ...
# ----------------------------------------------------------
# Under the response, each household is receiving a 50 kg bag of maize and two litres of cooking oil with pregnant mothers as well as those nursing children under the age of two receivingan extra 10kg of super cereal soya.
# ['response', 'household', 'receive', 'kg', 'bag', 'maize', 'two', 'litre', 'cook', 'oil', 'pregnant', 'mother', 'well', 'nurse', 'child', 'age', 'two', 'receivingan', 'extra', 'super', 'cereal', 'soya']
# ----------------------------------------------------------
# can you tell me where i can go to get a tent?
# ['tell', 'go', 'get', 'tent']
# ----------------------------------------------------------
# Hoping to my neighbors while we wait for plumbing and water to come back !
# ['hop', 'neighbor', 'wait', 'plumbing', 'water', 'come', 'back']
# ----------------------------------------------------------
# I want to activate savis pm in L
# ['want', 'activate', 'savis', 'pm', 'l']
# ----------------------------------------------------------
# At vifranc street ( near of Bolos ) lots of people who need water, food please help us
# ['vifranc', 'street', 'near', 'bolos', 'lot', 'people', 'need', 'water', 'food', 'please', 'help', 'u']
# ----------------------------------------------------------
# I'd like to know the info you're giving
# ['would', 'like', 'know', 'info', 'give']
# ----------------------------------------------------------
# The TNI will also send one infantry unit from Bireuen to Simeulue by ship.
# ['tni', 'also', 'send', 'one', 'infantry', 'unit', 'bireuen', 'simeulue', 'ship']
# ----------------------------------------------------------
# Talking to families in their homes about nutritious diets and healthful household behaviours is part of the fight against stunting in Bangladesh.
# ['talk', 'family', 'home', 'nutritious', 'diet', 'healthful', 'household', 'behaviour', 'part', 'fight', 'stunt', 'bangladesh']
# ----------------------------------------------------------
# Waiting for the days assignment . Still without power at home , but so grateful all of our friends are safe . #SandyABC7
# ['wait', 'day', 'assignment', 'still', 'without', 'power', 'home', 'grateful', 'friend', 'safe', 'sandyabc7']
# ----------------------------------------------------------
# .. . Now were in Gonaives zone Kanal Bwa i send this message. ..
# ['gonaives', 'zone', 'kanal', 'bwa', 'send', 'message']
# ----------------------------------------------------------
# goodevening, is this year that we are going to have the other earthquakes i hear that are coming? we have a lot of problems, please send a message for me, its oriental
# ['goodevening', 'year', 'go', 'earthquake', 'hear', 'come', 'lot', 'problem', 'please', 'send', 'message', 'oriental']
# ----------------------------------------------------------
# According to the agreement, the grant will be used to purchase fertilizers that aimed at improving the food security for underprivileged farmers in the country.
# ['accord', 'agreement', 'grant', 'use', 'purchase', 'fertilizer', 'aim', 'improve', 'food', 'security', 'underprivileged', 'farmer', 'country']
# ----------------------------------------------------------
# Early prospects are favorable for 2002/03 winter grains, with adequate winter precipitation recharging soil-moisture reserves.
# ['early', 'prospect', 'favorable', 'winter', 'grain', 'adequate', 'winter', 'precipitation', 'recharge', 'soilmoisture', 'reserve']
# ----------------------------------------------------------
# I live in Belaire, I need ..
# ['live', 'belaire', 'need']
# ----------------------------------------------------------
# Similarly in 1999 and 2001, weather extremes caused the loss of 30 percent of livestock.
# ['similarly', 'weather', 'extreme', 'cause', 'loss', 'percent', 'livestock']
# ----------------------------------------------------------
# Each family received food rations including vegetable seeds, blankets, plastic sheeting, hand tools, clothing and cooking utensils and several watering cans for cultivation.
# ['family', 'receive', 'food', 'ration', 'include', 'vegetable', 'seed', 'blanket', 'plastic', 'sheet', 'hand', 'tool', 'clothing', 'cooking', 'utensil', 'several', 'watering', 'cultivation']
# ----------------------------------------------------------
# i have general hand tools- drill , saw , etc .
# ['general', 'hand', 'tool', 'drill', 'saw', 'etc']
# ----------------------------------------------------------
# I want to sign up in the 4636 program. What do I do?
# ['want', 'sign', 'program']
# ----------------------------------------------------------
# I have urine problem and they don't tell what to do. help to have a urine test done please.
# ['urine', 'problem', 'tell', 'help', 'urine', 'test', 'please']
# ----------------------------------------------------------
# #Chillan is affected, but Thanks to God, not as affected as #Concepcion or #Talca. #earthquakeChile #Chile #earthquake
# ['chillan', 'affect', 'thanks', 'god', 'affect', 'concepcion', 'talca', 'earthquakechile', 'chile', 'earthquake']
# ----------------------------------------------------------
# They're in 265 dormitories around the country, in situations where they have extremely poor heating and very limited food supply and they're actually unable to get food to these children," she said.
# ['dormitory', 'around', 'country', 'situation', 'extremely', 'poor', 'heating', 'limited', 'food', 'supply', 'actually', 'unable', 'get', 'food', 'child', 'say']
# ----------------------------------------------------------
# A 3 -D relief projection shows the expression of this fault not only in the surface geology, but also in the surface geomorphology.
# ['relief', 'projection', 'show', 'expression', 'fault', 'surface', 'geology', 'also', 'surface', 'geomorphology']
# ----------------------------------------------------------
# their o.n.g. must to stop give food in the capital.pam especially.
# ['ong', 'must', 'stop', 'give', 'food', 'capitalpam', 'especially']
# ----------------------------------------------------------
# #FEMA .. Hmmm .. @WFSBnews Malloy : FEMA to be on ground in CT by Sunday #sandy #wfsb
# ['fema', 'hmmm', 'wfsbnews', 'malloy', 'fema', 'ground', 'ct', 'sunday', 'sandy', 'wfsb']
# ----------------------------------------------------------
# BUDGET: $650,559 which includes $560,688 in direct program assistance costs, including disaster preparedness trainings; school retrofitting, vocational trainings, permanent family sanitation facilities; provision of wells and pumps.
# ['budget', 'include', 'direct', 'program', 'assistance', 'cost', 'include', 'disaster', 'preparedness', 'training', 'school', 'retrofit', 'vocational', 'training', 'permanent', 'family', 'sanitation', 'facility', 'provision', 'well', 'pump']
# ----------------------------------------------------------
# I urge everyone to support the NGOs' fundraising campaigns. No problems have been reported at the common spent fuel pool. River barriers that North Korean authorities built to help irrigate crops affected by a recent drought may have contributed to the destruction caused by floods in certain parts of the country, sources inside the isolated nation said. Prime Minister inspects damage to embankment of Pyidawtha-Yegyanbyin railroad section. Support to national health structures in undertaking mass measles immunisation campaigns is being accelerated. The widespread addition of iodine to salt has almost eliminated goitre and other iodine deficiency symptoms in many countries. Not all survivors of the virus, which has been rampant in Guinea, Liberia and Sierra Leone since earlier this year and killed some 70 percent of patients, suffer the symptoms, the extremes of which include amenorrhea (the absence of menstruation) and erectile dysfunction. Relief workers were especially concerned that marooned villagers were being forced to drink contaminated floodwater, thus exacerbating the risk of water-borne disease, especially among children and the elderly. We are particularly worried about Somalia right now and it is vital that we reach those at the epicentre of the famine with food assistance  -  especially the highly fortified nutritious products that are so important for vulnerable children. OCHA is prepared to serve as a channel for cash contributions to be used for immediate relief assisstance, in coordination with relavent organizations in the United Nations system. Sudan's health ministry is distributing chlorine to sterilise water, repairing latrines and spraying insecticides to try to stop the spread of cholera and malaria after the worst floods in living memory. Despite these moves towards more permanent arrangements, a large number of displaced people remain camped in public buildings and tented accommodation. An FAO/WFP Crop and Food Supply Assessment Mission visited Zimbabwe from 25 April to 11 May 2001 to estimate the production of the main season cereal and pulse crops, forecast the 2001/02 winter season production and assess food import requirements. Terrorist attacks or flare up of violence are considered possible especially in the view of winter coming and during Ramadan which usually shows an increase of such activities by extremist militants. It has been set up with the purpose of choosing Afghanistan's first freely elected government in twenty-three years. In efforts aimed at finding a lasting solution to the problem that has become recurrent, Katima Mulilo mayor, Charles Matengu said the council is looking at sourcing a standby generator in order to avert a similar situation in future. The club is distributing bottled water, dry food (peanuts, roasted gram, rice, jaggery), food, clothes, and tarpaulins. Our patients continued to be mostly women and children suffering from dehydration, presumed malaria, respiratory infections, dysentery, diarrhea rashes and injuries. The classic problem of providing assistance to war criminals or 'genocidaires' who found themselves among the hundreds of thousands of refugees in camps in Eastern Zaire and Tanzania would not have emerged if UNHCR and states had implemented the Refugee Convention and had separated (and prosecuted) these people from genuine refugees. Besides supplying the initial starter seed paddy and agro-chemicals, Wanigasuriya and his officers provide valuable advice on planting techniques, weed control and harvesting times. Now that the rainy period has started water is all over the place, but it is highly polluted. (b) Sierra Leonean refugees displaced in south-east Guinea continue to be repatriated to Freetown. The first two years' work involves dredging 67.5km of key channel systems and four retention basins, as well as repairing 42km of embankments, the report said. As we recognize the importance of the smooth management of refugee areas and improving their cap ...
# ['urge', 'everyone', 'support', 'ngos', 'fundraising', 'campaign', 'problem', 'report', 'common', 'spent', 'fuel', 'pool', 'river', 'barrier', 'north', 'korean', 'authority', 'build', 'help', 'irrigate', 'crop', 'affect', 'recent', 'drought', 'may', 'contribute', 'destruction', 'cause', 'flood', 'certain', 'part', 'country', 'source', 'inside', 'isolated', 'nation', 'say', 'prime', 'minister', 'inspects', 'damage', 'embankment', 'pyidawthayegyanbyin', 'railroad', 'section', 'support', 'national', 'health', 'structure', 'undertake', 'mass', 'measles', 'immunisation', 'campaign', 'accelerate', 'widespread', 'addition', 'iodine', 'salt', 'almost', 'eliminate', 'goitre', 'iodine', 'deficiency', 'symptom', 'many', 'country', 'survivor', 'virus', 'rampant', 'guinea', 'liberia', 'sierra', 'leone', 'since', 'earlier', 'year', 'kill', 'percent', 'patient', 'suffer', 'symptom', 'extreme', 'include', 'amenorrhea', 'absence', 'menstruation', 'erectile', 'dysfunction', 'relief', 'worker', 'especially', 'concern', 'maroon', 'villager', 'force', 'drink', 'contaminated', 'floodwater', 'thus', 'exacerbate', 'risk', 'waterborne', 'disease', 'especially', 'among', 'child', 'elderly', 'particularly', 'worry', 'somalia', 'right', 'vital', 'reach', 'epicentre', 'famine', 'food', 'assistance', 'especially', 'highly', 'fortify', 'nutritious', 'product', 'important', 'vulnerable', 'child', 'ocha', 'prepared', 'serve', 'channel', 'cash', 'contribution', 'use', 'immediate', 'relief', 'assisstance', 'coordination', 'relavent', 'organization', 'united', 'nation', 'system', 'sudans', 'health', 'ministry', 'distribute', 'chlorine', 'sterilise', 'water', 'repair', 'latrine', 'spray', 'insecticide', 'try', 'stop', 'spread', 'cholera', 'malaria', 'bad', 'flood', 'live', 'memory', 'despite', 'move', 'towards', 'permanent', 'arrangement', 'large', 'number', 'displaced', 'people', 'remain', 'camped', 'public', 'building', 'tent', 'accommodation', 'faowfp', 'crop', 'food', 'supply', 'assessment', 'mission', 'visit', 'zimbabwe', 'april', 'may', 'estimate', 'production', 'main', 'season', 'cereal', 'pulse', 'crop', 'forecast', 'winter', 'season', 'production', 'ass', 'food', 'import', 'requirement', 'terrorist', 'attack', 'flare', 'violence', 'consider', 'possible', 'especially', 'view', 'winter', 'come', 'ramadan', 'usually', 'show', 'increase', 'activity', 'extremist', 'militant', 'set', 'purpose', 'choose', 'afghanistan', 'first', 'freely', 'elected', 'government', 'twentythree', 'year', 'effort', 'aim', 'find', 'lasting', 'solution', 'problem', 'become', 'recurrent', 'katima', 'mulilo', 'mayor', 'charles', 'matengu', 'say', 'council', 'look', 'source', 'standby', 'generator', 'order', 'avert', 'similar', 'situation', 'future', 'club', 'distribute', 'bottled', 'water', 'dry', 'food', 'peanut', 'roast', 'gram', 'rice', 'jaggery', 'food', 'clothes', 'tarpaulins', 'patient', 'continue', 'mostly', 'woman', 'child', 'suffer', 'dehydration', 'presume', 'malaria', 'respiratory', 'infection', 'dysentery', 'diarrhea', 'rash', 'injuries', 'classic', 'problem', 'provide', 'assistance', 'war', 'criminal', 'genocidaires', 'find', 'among', 'hundred', 'thousand', 'refugee', 'camp', 'eastern', 'zaire', 'tanzania', 'would', 'emerge', 'unhcr', 'state', 'implement', 'refugee', 'convention', 'separate', 'prosecute', 'people', 'genuine', 'refugee', 'besides', 'supply', 'initial', 'starter', 'seed', 'paddy', 'agrochemicals', 'wanigasuriya', 'officer', 'provide', 'valuable', 'advice', 'plant', 'technique', 'weed', 'control', 'harvest', 'time', 'rainy', 'period', 'start', 'water', 'place', 'highly', 'polluted', 'b', 'sierra', 'leonean', 'refugee', 'displace', 'southeast', 'guinea', 'continue', 'repatriate', 'freetown', 'first', 'two', 'year', 'work', 'involve', 'dredge', 'key', 'channel', 'system', 'four', 'retention', 'basin', 'well', 'repair', 'embankment', 'report', 'say', 'recognize', 'importance', 'smooth', 'management', 'refugee', 'area', 'improve', 'capability', 'stock', 'adequat ...
# ----------------------------------------------------------
# I would like to leave this country and at my parents house in the USA. We are alone in Haiti. This is my number
# ['would', 'like', 'leave', 'country', 'parent', 'house', 'usa', 'alone', 'haiti', 'number']
# ----------------------------------------------------------
# When will there be another earthquake again?
# ['another', 'earthquake']
# ----------------------------------------------------------
# I need a free cell phone please I love digicel
# ['need', 'free', 'cell', 'phone', 'please', 'love', 'digicel']
# ----------------------------------------------------------
# Villagers continue with makeshift repairs in bitter sub-zero weather.
# ['villager', 'continue', 'makeshift', 'repair', 'bitter', 'subzero', 'weather']
# ----------------------------------------------------------
# NPPR only applies to those displaced due to development projects and is primarily meant to safeguard the interests of resource-poor landless agricultural labourers, forest dwellers, artisans and adivasi groups.
# ['nppr', 'apply', 'displace', 'due', 'development', 'project', 'primarily', 'mean', 'safeguard', 'interest', 'resourcepoor', 'landless', 'agricultural', 'labourer', 'forest', 'dweller', 'artisan', 'adivasi', 'group']

# %%
h_tokenize = lambda elem: tokenize(elem,
                                   english_stopwords,
                                   lemmatizer)

# %%
vectorizer = TfidfVectorizer(tokenizer=h_tokenize, lowercase=False)
bag_of_words = vectorizer.fit_transform(X_train)

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = 

cv =

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
